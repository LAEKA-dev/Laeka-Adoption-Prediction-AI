# %%
import numpy as np 
import pandas as pd 

import os
os.listdir('/kaggle/input/petfinder-adoption-prediction/n')
# You can write up to 20GB to the current directory (/kaggle/working/) that gets preserved as output when you create a version using "Save & Run All" 
# You can also write temporary files to /kaggle/temp/, but they won't be saved outside of the current session
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# <ipython-input-1-90687a8bb726> in <module>
#       3
#       4 import os
# ----> 5 os.listdir('/kaggle/input/petfinder-adoption-prediction/n')
#       6 # You can write up to 20GB to the current directory (/kaggle/working/) that gets preserved as output when you create a version using "Save & Run All"
#       7 # You can also write temporary files to /kaggle/temp/, but they won't be saved outside of the current session
#
# FileNotFoundError: [Errno 2] No such file or directory: '/kaggle/input/petfinder-adoption-prediction/n'

# %%
train = pd.read_csv("/kaggle/input/petfinder-adoption-prediction/train/train.csv", index_col="PetID")
train
# Out:
#            Type            Name  Age  Breed1  Breed2  Gender  Color1  Color2  \
# PetID
# 86e1089a3     2          Nibble    3     299       0       1       1       7
# 6296e909a     2     No Name Yet    1     265       0       1       1       2
# 3422e4906     1          Brisco    1     307       0       1       2       7
# 5842f1ff5     1            Miko    4     307       0       2       1       2
# 850a43f90     1          Hunter    1     307       0       1       1       0
# ...         ...             ...  ...     ...     ...     ...     ...     ...
# dc0935a84     2             NaN    2     266       0       3       1       0
# a01ab5b30     2  Serato & Eddie   60     265     264       3       1       4
# d981b6395     2         Monkies    2     265     266       3       5       6
# e4da1c9e4     2         Ms Daym    9     266       0       2       4       7
# a83d95ead     1            Fili    1     307     307       1       2       0
#
#            Color3  MaturitySize  ...  Sterilized  Health  Quantity  Fee  \
# PetID                            ...
# 86e1089a3       0             1  ...           2       1         1  100
# 6296e909a       0             2  ...           3       1         1    0
# 3422e4906       0             2  ...           2       1         1    0
# 5842f1ff5       0             2  ...           2       1         1  150
# 850a43f90       0             2  ...           2       1         1    0
# ...           ...           ...  ...         ...     ...       ...  ...
# dc0935a84       0             2  ...           2       1         4    0
# a01ab5b30       7             2  ...           1       1         2    0
# d981b6395       7             3  ...           3       1         5   30
# e4da1c9e4       0             1  ...           1       1         1    0
# a83d95ead       0             2  ...           2       1         1    0
#
#            State                         RescuerID  VideoAmt  \
# PetID
# 86e1089a3  41326  8480853f516546f6cf33aa88cd76c379         0
# 6296e909a  41401  3082c7125d8fb66f7dd4bff4192c8b14         0
# 3422e4906  41326  fa90fa5b1ee11c86938398b60abc32cb         0
# 5842f1ff5  41401  9238e4f44c71a75282e62f7136c6b240         0
# 850a43f90  41326  95481e953f8aed9ec3d16fc4509537e8         0
# ...          ...                               ...       ...
# dc0935a84  41326  61c84bd7bcb6fb31d2d480b1bcf9682e         0
# a01ab5b30  41326  1d5096c4a5e159a3b750c5cfcf6ceabf         0
# d981b6395  41326  6f40a7acfad5cc0bb3e44591ea446c05         0
# e4da1c9e4  41336  c311c0c569245baa147d91fa4e351ae4         0
# a83d95ead  41332  9ed1d5493d223eaa5024c1a031dbc9c2         0
#
#                                                  Description PhotoAmt  \
# PetID
# 86e1089a3  Nibble is a 3+ month old ball of cuteness. He ...      1.0
# 6296e909a  I just found it alone yesterday near my apartm...      2.0
# 3422e4906  Their pregnant mother was dumped by her irresp...      7.0
# 5842f1ff5  Good guard dog, very alert, active, obedience ...      8.0
# 850a43f90  This handsome yet cute boy is up for adoption....      3.0
# ...                                                      ...      ...
# dc0935a84  I have 4 kittens that need to be adopt urgentl...      3.0
# a01ab5b30  Serato(female cat- 3 color) is 4 years old and...      3.0
# d981b6395  Mix breed, good temperament kittens. Love huma...      5.0
# e4da1c9e4  she is very shy..adventures and independent..s...      3.0
# a83d95ead  Fili just loves laying around and also loves b...      1.0
#
#            AdoptionSpeed
# PetID
# 86e1089a3              2
# 6296e909a              0
# 3422e4906              3
# 5842f1ff5              2
# 850a43f90              2
# ...                  ...
# dc0935a84              2
# a01ab5b30              4
# d981b6395              3
# e4da1c9e4              4
# a83d95ead              3
#
# [14993 rows x 23 columns]

# %%
test = pd.read_csv("/kaggle/input/petfinder-adoption-prediction/test/test.csv", index_col="PetID")
test
# Out:
#            Type                       Name  Age  Breed1  Breed2  Gender  \
# PetID
# e2dfc2935     2               Dopey & Grey    8     266     266       1
# f153b465f     2                    Chi Chi   36     285     264       2
# 3c90f3f54     2                     Sticky    2     265       0       1
# e02abc8a3     1  Dannie & Kass [In Penang]   12     307       0       2
# 09f0df7d1     2                    Cuddles   12     265       0       1
# ...         ...                        ...  ...     ...     ...     ...
# ae57f8d52     1                       Hugo    5     307     307       1
# 83432904d     1                       Spot   30     307     307       1
# 399013029     2                        NaN    5     300       0       3
# fd80b8c80     1                     Smokey   24     307       0       2
# 493ed84ae     2                        NaN    1     266       0       3
#
#            Color1  Color2  Color3  MaturitySize  ...  Dewormed  Sterilized  \
# PetID                                            ...
# e2dfc2935       2       6       7             1  ...         1           2
# f153b465f       1       4       7             2  ...         1           1
# 3c90f3f54       6       7       0             2  ...         1           2
# e02abc8a3       2       5       0             2  ...         1           1
# 09f0df7d1       2       3       7             2  ...         1           1
# ...           ...     ...     ...           ...  ...       ...         ...
# ae57f8d52       1       2       0             2  ...         1           2
# 83432904d       1       2       7             2  ...         1           2
# 399013029       1       2       4             2  ...         3           2
# fd80b8c80       5       7       0             2  ...         2           2
# 493ed84ae       1       7       0             1  ...         3           2
#
#            Health  Quantity  Fee  State                         RescuerID  \
# PetID
# e2dfc2935       1         2    0  41326  2ece3b2573dcdcebd774e635dca15fd9
# f153b465f       2         1    0  41326  2ece3b2573dcdcebd774e635dca15fd9
# 3c90f3f54       1         1  200  41326  e59c106e9912fa30c898976278c2e834
# e02abc8a3       1         2    0  41326  e59c106e9912fa30c898976278c2e834
# 09f0df7d1       1         1    0  41326  e59c106e9912fa30c898976278c2e834
# ...           ...       ...  ...    ...                               ...
# ae57f8d52       1         2  150  41401  18ec8ca4486bc2760de0bd5390cee30c
# 83432904d       1         1    0  41326  d83be5f5e2d04e24d7376e99eafd8708
# 399013029       1         6    0  41401  30aa45fdbe45e39d5614ef583b569073
# fd80b8c80       1         1    0  41325  087903c2819a6297519c93d962b488d5
# 493ed84ae       1         6    0  41326  041876679ae0261e3ee4aefe9e66316f
#
#            VideoAmt                                        Description  \
# PetID
# e2dfc2935         0  Dopey Age: 8mths old Male One half of a pair, ...
# f153b465f         0  Please note that Chichi has been neutered, the...
# 3c90f3f54         0  Sticky, named such because of his tendency to ...
# e02abc8a3         0  Dannie and Kass are mother and daughter. We en...
# 09f0df7d1         0  Extremely cuddly cat, hence the origin of his ...
# ...             ...                                                ...
# ae57f8d52         0  Found on the streets. Treated for mange. They ...
# 83432904d         0  Very good guard dog. Healthy was found in Fron...
# 399013029         0  these cat's mother was killed when they was ne...
# fd80b8c80         0  smokey is good family pet. very obedient,so lo...
# 493ed84ae         0  Found abandoned with the mother at nearby shop...
#
#            PhotoAmt
# PetID
# e2dfc2935       2.0
# f153b465f       1.0
# 3c90f3f54       4.0
# e02abc8a3       5.0
# 09f0df7d1       5.0
# ...             ...
# ae57f8d52       5.0
# 83432904d       2.0
# 399013029       1.0
# fd80b8c80       3.0
# 493ed84ae       1.0
#
# [3972 rows x 22 columns]

# %%
train.columns
# Out:
# Index(['Type', 'Name', 'Age', 'Breed1', 'Breed2', 'Gender', 'Color1', 'Color2',
#        'Color3', 'MaturitySize', 'FurLength', 'Vaccinated', 'Dewormed',
#        'Sterilized', 'Health', 'Quantity', 'Fee', 'State', 'RescuerID',
#        'VideoAmt', 'Description', 'PhotoAmt', 'AdoptionSpeed'],
#       dtype='object')

# %%
train.AdoptionSpeed.value_counts().sort_index().rename("freq").to_frame().join(train.AdoptionSpeed.value_counts(1).rename("freq_rel"))
# Out:
#    freq  freq_rel
# 0   410  0.027346
# 1  3090  0.206096
# 2  4037  0.269259
# 3  3259  0.217368
# 4  4197  0.279931

# %%
train.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 14993 entries, 86e1089a3 to a83d95ead
# Data columns (total 23 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   Type           14993 non-null  int64
#  1   Name           13736 non-null  object
#  2   Age            14993 non-null  int64
#  3   Breed1         14993 non-null  int64
#  4   Breed2         14993 non-null  int64
#  5   Gender         14993 non-null  int64
#  6   Color1         14993 non-null  int64
#  7   Color2         14993 non-null  int64
#  8   Color3         14993 non-null  int64
#  9   MaturitySize   14993 non-null  int64
#  10  FurLength      14993 non-null  int64
#  11  Vaccinated     14993 non-null  int64
#  12  Dewormed       14993 non-null  int64
#  13  Sterilized     14993 non-null  int64
#  14  Health         14993 non-null  int64
#  15  Quantity       14993 non-null  int64
#  16  Fee            14993 non-null  int64
#  17  State          14993 non-null  int64
#  18  RescuerID      14993 non-null  object
#  19  VideoAmt       14993 non-null  int64
#  20  Description    14981 non-null  object
#  21  PhotoAmt       14993 non-null  float64
#  22  AdoptionSpeed  14993 non-null  int64
# dtypes: float64(1), int64(19), object(3)
# memory usage: 2.7+ MB

# %%
pd.crosstab(train.VideoAmt, train.AdoptionSpeed)
# Out:
# AdoptionSpeed    0     1     2     3     4
# VideoAmt
# 0              390  2990  3859  3104  4076
# 1               16    75   130   109    87
# 2                3    17    29    29    14
# 3                1     5    13     7    10
# 4                0     1     3     5     6
# 5                0     1     2     3     1
# 6                0     1     0     1     2
# 7                0     0     1     0     0
# 8                0     0     0     1     1

# %%
pd.crosstab(train.VideoAmt, train.AdoptionSpeed).apply(lambda x: x / x.sum(), axis=1)
# Out:
# AdoptionSpeed         0         1         2         3         4
# VideoAmt
# 0              0.027048  0.207365  0.267633  0.215272  0.282683
# 1              0.038369  0.179856  0.311751  0.261391  0.208633
# 2              0.032609  0.184783  0.315217  0.315217  0.152174
# 3              0.027778  0.138889  0.361111  0.194444  0.277778
# 4              0.000000  0.066667  0.200000  0.333333  0.400000
# 5              0.000000  0.142857  0.285714  0.428571  0.142857
# 6              0.000000  0.250000  0.000000  0.250000  0.500000
# 7              0.000000  0.000000  1.000000  0.000000  0.000000
# 8              0.000000  0.000000  0.000000  0.500000  0.500000

# %%
pd.crosstab(train.PhotoAmt, train.AdoptionSpeed)
# Out:
# AdoptionSpeed   0    1    2    3     4
# PhotoAmt
# 0.0            24   34   36   34   213
# 1.0            75  615  783  592  1010
# 2.0            83  523  665  496   751
# 3.0            75  561  666  487   722
# 4.0            45  424  520  402   490
# 5.0            65  495  609  433   545
# 6.0            15  121  174  176   135
# 7.0             6   83  151  128    64
# 8.0             6   58   93   99    58
# 9.0             2   34   76   87    32
# 10.0            4   30   52   67    37
# 11.0            2   35   58   54    35
# 12.0            2   19   26   35    15
# 13.0            1   14   24   33    14
# 14.0            0    6   26   29    17
# 15.0            2    7   15   16    10
# 16.0            0    4   15   14     6
# 17.0            0    5   10    7     5
# 18.0            0    0    6    8     4
# 19.0            2    4    2    9     3
# 20.0            0    8    2    8     7
# 21.0            0    0    6    7     3
# 22.0            0    0    3    6     0
# 23.0            0    2    3    5     2
# 24.0            0    1    4    2     8
# 25.0            0    3    0    3     2
# 26.0            0    1    2    5     2
# 27.0            1    1    1    2     1
# 28.0            0    1    0    5     1
# 29.0            0    0    0    4     2
# 30.0            0    1    9    6     3

# %%
pd.crosstab(train.PhotoAmt.clip(0, 10), train.AdoptionSpeed).apply(lambda x: x / x.sum(), axis=1)
# Out:
# AdoptionSpeed         0         1         2         3         4
# PhotoAmt
# 0.0            0.070381  0.099707  0.105572  0.099707  0.624633
# 1.0            0.024390  0.200000  0.254634  0.192520  0.328455
# 2.0            0.032963  0.207705  0.264098  0.196982  0.298253
# 3.0            0.029869  0.223417  0.265233  0.193947  0.287535
# 4.0            0.023923  0.225412  0.276449  0.213716  0.260500
# 5.0            0.030275  0.230554  0.283652  0.201677  0.253843
# 6.0            0.024155  0.194847  0.280193  0.283414  0.217391
# 7.0            0.013889  0.192130  0.349537  0.296296  0.148148
# 8.0            0.019108  0.184713  0.296178  0.315287  0.184713
# 9.0            0.008658  0.147186  0.329004  0.376623  0.138528
# 10.0           0.015184  0.154013  0.286334  0.352495  0.191974

# %%
from lightgbm import LGBMClassifier
from sklearn.model_selection import StratifiedKFold
from sklearn.metrics import cohen_kappa_score

def trainModel(train, test, target="AdoptionSpeed"):
    kf = StratifiedKFold(n_splits=5, shuffle=True, random_state=1)
    folds = [(train.iloc[train_idx].index, train.iloc[valid_idx].index)
             for train_idx, valid_idx in kf.split(train.drop(target, axis=1), train.AdoptionSpeed)]
    test_probs = pd.DataFrame(np.zeros((test.shape[0], train.AdoptionSpeed.nunique())), index=test.index)
    valid_probs = []
#     out-of-fold probs
    for i, (train_idx, valid_idx) in enumerate(folds):
        X_train = train.loc[train_idx]
        y_train = X_train[target]
        X_train = X_train.drop(target, axis=1)
        
        X_valid = train.loc[valid_idx]
        y_valid = X_valid[target]
        X_valid = X_valid.drop(target, axis=1)
        
        learner = LGBMClassifier(n_estimators=10000)
        learner.fit(X_train, y_train,  early_stopping_rounds=10, eval_metric="multi_logloss", verbose=100,
                    eval_set=[(X_train, y_train),
                              (X_valid, y_valid)])
        probs = pd.Series(learner.predict_proba(X_valid).argmax(axis=1), index=X_valid.index)
        valid_probs.append(probs)
        res = cohen_kappa_score(y_valid, probs, weights='quadratic')
        print(f"para el fold {i + 1} el resultado fue: {res}")
        test_probs += learner.predict_proba(test)
    valid_probs = pd.concat(valid_probs)
    res = cohen_kappa_score(train.AdoptionSpeed.loc[valid_probs.index], valid_probs, weights='quadratic')
    print(f"Resultado Final: {res}")
    return test_probs.idxmax(axis=1).rename(target)

# %%
train.Description.fillna("", inplace=True)
test.Description.fillna("", inplace=True)

# %%
from sklearn.feature_extraction.text import TfidfVectorizer
from sklearn.decomposition import TruncatedSVD

vectorizer = TfidfVectorizer()
svd = TruncatedSVD(n_components=25, n_iter=7, random_state=42)


train = train.join(pd.DataFrame(svd.fit_transform(vectorizer.fit_transform(train.Description.fillna(""))), index=train.index, columns=[f"svd_{i}" for i in range(25)]))
test = test.join(pd.DataFrame(svd.transform(vectorizer.transform(test.Description.fillna(""))), index=test.index, columns=[f"svd_{i}" for i in range(25)]))

# %%
for c in train.select_dtypes("O"):
    train[c] = train[c].astype("category")
    test[c] = test[c].astype("category")

# %%
test_preds = trainModel(train, test)
# Out:
# Training until validation scores don't improve for 10 rounds
# Early stopping, best iteration is:
# [74]	training's multi_logloss: 0.919345	valid_1's multi_logloss: 1.28653
# para el fold 1 el resultado fue: 0.3785650168179644
# Training until validation scores don't improve for 10 rounds
# Early stopping, best iteration is:
# [83]	training's multi_logloss: 0.889497	valid_1's multi_logloss: 1.27307
# para el fold 2 el resultado fue: 0.37075418545303784
# Training until validation scores don't improve for 10 rounds
# Early stopping, best iteration is:
# [82]	training's multi_logloss: 0.895205	valid_1's multi_logloss: 1.28805
# para el fold 3 el resultado fue: 0.370105228010559
# Training until validation scores don't improve for 10 rounds
# Early stopping, best iteration is:
# [77]	training's multi_logloss: 0.90653	valid_1's multi_logloss: 1.30155
# para el fold 4 el resultado fue: 0.34955391227725796
# Training until validation scores don't improve for 10 rounds
# Early stopping, best iteration is:
# [65]	training's multi_logloss: 0.949875	valid_1's multi_logloss: 1.30417
# para el fold 5 el resultado fue: 0.36926629649066633
# Resultado Final: 0.36764861945545757

# %%
for c in ["Breed1", "Breed2", "Gender", "Color1", "Color2", "Color3", "State", "MaturitySize", "Vaccinated","Dewormed","Sterilized","Health"]:
    train[c] = train[c].astype("category")
    test[c] = test[c].astype("category")

# %%
test_preds = trainModel(train, test)
# Out:
# Training until validation scores don't improve for 10 rounds
# Early stopping, best iteration is:
# [58]	training's multi_logloss: 0.962219	valid_1's multi_logloss: 1.2906
# para el fold 1 el resultado fue: 0.37633255021568857
# Training until validation scores don't improve for 10 rounds
# [100]	training's multi_logloss: 0.815909	valid_1's multi_logloss: 1.26757
# Early stopping, best iteration is:
# [108]	training's multi_logloss: 0.793381	valid_1's multi_logloss: 1.26708
# para el fold 2 el resultado fue: 0.3959205817531345
# Training until validation scores don't improve for 10 rounds
# Early stopping, best iteration is:
# [79]	training's multi_logloss: 0.88538	valid_1's multi_logloss: 1.28713
# para el fold 3 el resultado fue: 0.4045157156464577
# Training until validation scores don't improve for 10 rounds
# Early stopping, best iteration is:
# [79]	training's multi_logloss: 0.881234	valid_1's multi_logloss: 1.30677
# para el fold 4 el resultado fue: 0.35600834834545647
# Training until validation scores don't improve for 10 rounds
# Early stopping, best iteration is:
# [78]	training's multi_logloss: 0.886755	valid_1's multi_logloss: 1.30355
# para el fold 5 el resultado fue: 0.3725259181900701
# Resultado Final: 0.3809628062875793

# %%
train["gage"] = pd.factorize(pd.qcut(train.Age, 5))[0]
test["gage"] = pd.factorize(pd.qcut(test.Age, 5).astype("category"))[0]

# %%
train["playful"] = train['Description'].str.contains('playful').fillna(0).astype(int)
test["playful"] = test['Description'].str.contains('playful').fillna(0).astype(int)
test_preds = trainModel(train, test)
# Out:
# Training until validation scores don't improve for 10 rounds
# Early stopping, best iteration is:
# [51]	training's multi_logloss: 0.991533	valid_1's multi_logloss: 1.29428
# para el fold 1 el resultado fue: 0.3691360142522885
# Training until validation scores don't improve for 10 rounds
# Early stopping, best iteration is:
# [78]	training's multi_logloss: 0.888191	valid_1's multi_logloss: 1.26751
# para el fold 2 el resultado fue: 0.3855624421128676
# Training until validation scores don't improve for 10 rounds
# [100]	training's multi_logloss: 0.817192	valid_1's multi_logloss: 1.28927
# Early stopping, best iteration is:
# [98]	training's multi_logloss: 0.822917	valid_1's multi_logloss: 1.28862
# para el fold 3 el resultado fue: 0.39248185155930515
# Training until validation scores don't improve for 10 rounds
# Early stopping, best iteration is:
# [67]	training's multi_logloss: 0.923565	valid_1's multi_logloss: 1.31186
# para el fold 4 el resultado fue: 0.3414814935380236
# Training until validation scores don't improve for 10 rounds
# Early stopping, best iteration is:
# [71]	training's multi_logloss: 0.910269	valid_1's multi_logloss: 1.30594
# para el fold 5 el resultado fue: 0.3838664218269541
# Resultado Final: 0.37443897243977875

# %%
train["desc_len"] = train.Description.str.len().fillna(0)
test["desc_len"] = test.Description.str.len().fillna(0)
test_preds = trainModel(train, test)
# Out:
# Training until validation scores don't improve for 10 rounds
# Early stopping, best iteration is:
# [59]	training's multi_logloss: 0.955686	valid_1's multi_logloss: 1.28822
# para el fold 1 el resultado fue: 0.37330662096291145
# Training until validation scores don't improve for 10 rounds
# [100]	training's multi_logloss: 0.812353	valid_1's multi_logloss: 1.26572
# Early stopping, best iteration is:
# [91]	training's multi_logloss: 0.839433	valid_1's multi_logloss: 1.26549
# para el fold 2 el resultado fue: 0.3855778375006331
# Training until validation scores don't improve for 10 rounds
# [100]	training's multi_logloss: 0.817345	valid_1's multi_logloss: 1.28789
# Early stopping, best iteration is:
# [93]	training's multi_logloss: 0.838456	valid_1's multi_logloss: 1.28647
# para el fold 3 el resultado fue: 0.40287393402563887
# Training until validation scores don't improve for 10 rounds
# Early stopping, best iteration is:
# [78]	training's multi_logloss: 0.881866	valid_1's multi_logloss: 1.30192
# para el fold 4 el resultado fue: 0.3483674079614806
# Training until validation scores don't improve for 10 rounds
# Early stopping, best iteration is:
# [65]	training's multi_logloss: 0.931256	valid_1's multi_logloss: 1.29989
# para el fold 5 el resultado fue: 0.3753848826331784
# Resultado Final: 0.3771280804530852

# %%
test_preds.to_csv("submission.csv")
